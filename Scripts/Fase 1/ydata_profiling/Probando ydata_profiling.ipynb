# %%
# !pip install ydata-profiling

# %%
import numpy as np
import pandas as pd
import ydata_profiling as ydp
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %% [markdown]
# Cargo los datasets:

# %%
rutaL1 = '../Datos/L1'

L1_booksRatings = pd.read_csv(rutaL1 + '/Books_rating.csv')
L1_booksData = pd.read_csv(rutaL1 + '/books_data.csv')

# %%
rutaL2 = '../Datos/L2'

L2_books = pd.read_csv(rutaL2 + '/books.csv', encoding='latin1', sep=';', quotechar='"', engine='python',escapechar='\\')
L2_ratings = pd.read_csv(rutaL2 + '/ratings.csv', encoding='latin1', sep=';', quotechar='"', engine='python',escapechar='\\')
L2_users = pd.read_csv(rutaL2 + '/users.csv', encoding='latin1', sep=';', quotechar='"', engine='python',escapechar='\\')

# %% [markdown]
# Pruebo el profiling:

# %%
# L1 - Datasets
report_L1_booksRatings = ydp.ProfileReport(L1_booksRatings, title="L1_booksRatings Profile Report")
report_L1_booksRatings.to_file(output_file="report_L1_booksRatings.html")

# # esta version cnsume menos ram
# report_L1_booksRatings = ydp.ProfileReport(
#     L1_booksRatings,
#     title="L1_booksRatings Report",
#     correlations=None,
#     interactions=None,
#     explorative=False
# )
# report_L1_booksRatings.to_file(output_file="report_L1_booksRatings.html")

# %%
# !pip install dask[complete]
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 20.3 MB/s eta 0:00:00
# ...

# %%
report_L1_booksData = ydp.ProfileReport(L1_booksData, title="L1_booksData Profile Report")
report_L1_booksData.to_file(output_file="report_L1_booksData.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# L2 - Datasets
report_L2_books = ydp.ProfileReport(L2_books, title="L2_books Profile Report")
report_L2_books.to_file(output_file="report_L2_books.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
report_L2_ratings = ydp.ProfileReport(L2_ratings, title="L2_ratings Profile Report")
report_L2_ratings.to_file(output_file="report_L2_ratings.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
report_L2_users = ydp.ProfileReport(L2_users, title="L2_users Profile Report")
report_L2_users.to_file(output_file="report_L2_users.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
